# %%
#Hacemos lectura de nuestras librerías
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importamos todos los datasets

# %%
#importamos el dataseT llamado "music.csv"
musica = pd.read_csv("music.csv")

# %%
musica.shape
# Out:
# (384, 3)

# %%
#Como no se visualizan todos los datos, aplicamos el formato "style"
musica
# Out:
#      Year     Format  Revenue [m$]
# 0    1973        DVD           0.0
# 1    1973      Other           0.0
# 2    1973      Tapes        2941.0
# 3    1973   Download           0.0
# 4    1973  Streaming           0.0
# ..    ...        ...           ...
# 379  2020   Download         653.0
# 380  2020  Streaming       10075.0
# 381  2020   Cassette           0.0
# 382  2020      Vinyl         626.0
# 383  2020         CD         484.0
#
# [384 rows x 3 columns]

# %%
#Importamos la librería llamada "porcino.xlsx"
porcinos = pd.read_excel("porcino.xlsx")

# %%
porcinos.head()
# Out:
#     ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)   Sexo  \
# 0  NaN                    NaN                        NaN    NaN
# 1  1.0                   64.4                       55.8  MACHO
# 2  2.0                   64.0                       57.9  MACHO
# 3  3.0                   56.4                       58.8  MACHO
# 4  4.0                   69.2                       54.6  MACHO
#
#           Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# 0            NaN                 NaN                               NaN
# 1      O´Higgins          Execelente                              85.9
# 2      Araucania          Execelente                              80.4
# 3  Metropolitana          Execelente                              81.7
# 4  Metropolitana            Estandar                              88.6
#
#    Peso Canal Refrigerada (PCR - Kg)
# 0                                NaN
# 1                               84.3
# 2                               78.5
# ...

# %%
#Importamos la librería llamada "titanic.csv"
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      Count  PassengerId  Survived  Pclass  \
# 0        1            1      Died       3
# 1        1            2  Survived       1
# 2        1            3  Survived       3
# 3        1            4  Survived       1
# 4        1            5      Died       3
# ..     ...          ...       ...     ...
# 886      1          887      Died       2
# 887      1          888  Survived       1
# 888      1          889      Died       3
# 889      1          890  Survived       1
# 890      1          891      Died       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
#Importamos la librería llamada "w_university_r.csv"
universidad = pd.read_csv("w_university_r.csv")
universidad
# Out:
#       World Rank                                        Institution  \
# 0              1                                 Harvard University
# 1              2              Massachusetts Institute of Technology
# 2              3                                Stanford University
# 3              4                            University of Cambridge
# 4              5                               University of Oxford
# ...          ...                                                ...
# 1995        1996                           Bharathidasan University
# 1996        1997                     Federal University of Maranhão
# 1997        1998        Jiangxi University of Finance and Economics
# 1998        1999                             University of Tarapacá
# 1999        2000  National Institute of Mental Health and Neuros...
#
#             Location  National Rank Education Rank Employability Rank  \
# 0                USA              1              1                  1
# ...

# %%
universidad.describe()
# Out:
#         World Rank  National Rank        Score
# count  2000.000000    2000.000000  2000.000000
# mean   1000.500000      68.374000    71.586450
# std     577.494589      84.132189     5.079795
# min       1.000000       1.000000    65.700000
# 25%     500.750000      10.000000    67.700000
# 50%    1000.500000      33.000000    70.200000
# 75%    1500.250000      88.000000    74.100000
# max    2000.000000     335.000000   100.000000

# %%
#PREGUNTA 1
#sobre el archivo music.csv. ¿Cuál es el "Format"con el más alto valor en Revenue?
musica.max()
# Out:
# Year               2020
# Format            Vinyl
# Revenue [m$]    20255.0
# dtype: object

# %%
musica[musica["Revenue [m$]"]==musica["Revenue [m$]"].max()]
# Out:
#      Year Format  Revenue [m$]
# 215  1999     CD       20255.0

# %%
#PREGUNTA 2
#Sobre "porcino.xlsx". ¿Cuántos porcinos Hembra 
#tiene la calidad de carne "buena"?
p2 = porcinos[(porcinos["Calidad de la carne"] == "Buena") & (porcinos["Sexo"] == "HEMBRA")]
p2
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)    Sexo  \
# 344  344.0                   54.8                       48.3  HEMBRA
# 351  351.0                   50.0                       49.3  HEMBRA
# 373  373.0                   55.6                       49.8  HEMBRA
# 383  383.0                   60.8                       47.2  HEMBRA
#
#          Region Calidad de la carne  Peso Canal Caliente \n (PCC- Kg)  \
# 344   O´Higgins               Buena                              76.9
# 351   O´Higgins               Buena                              73.9
# 373  Valparaiso               Buena                              77.4
# 383   O´Higgins               Buena                             115.0
#
#      Peso Canal Refrigerada (PCR - Kg)
# 344                               71.9
# 351                               73.6
# 373                               72.8
# 383                              108.7

# %%
len(p2)
# Out:
# 4

# %%
#PREGUNTA 3
#Sobre "w_university_r.csv". ¿Cuántas universidad de Cyprus aparecen?
universidad[universidad["Location"]=="Cyprus"]
# Out:
#       World Rank                      Institution Location  National Rank  \
# 742          743             University of Cyprus   Cyprus              1
# 1728        1729  Cyprus University of Technology   Cyprus              2
#
#      Education Rank Employability Rank Faculty Rank Research Rank  Score
# 742               -                  -            -           703   72.0
# 1728              -                  -            -          1658   66.7

# %%
#PREGUNTA 4
#de "titanic.csv" ¿cuántas personas murieron?
p4=titanic[titanic["Survived"]=="Died"]
len(p4)
# Out:
# 549

# %%
#PREGUNTA 5
#De "music.csv". ¿El format Vinyl en qué años obtuvo el valor más
#alto en revenue?
p5=musica[musica["Format"] == "Vinyl"]
p5[p5["Revenue [m$]"]==p5["Revenue [m$]"].max()]
# Out:
#     Year Format  Revenue [m$]
# 46  1978  Vinyl       10851.0

# %%
#PREGUNTE 6
#De "porcino.xlsx". ¿Cuántos valores nulos tiene?
p6=porcinos.isnull()
p6
# Out:
#         ID  Espesor Lomo\n  (m.m)  Porcentaje Magro\n CM (%)   Sexo  Region  \
# 0     True                   True                       True   True    True
# 1    False                  False                      False  False   False
# 2    False                  False                      False  False   False
# 3    False                  False                      False  False   False
# 4    False                  False                      False  False   False
# ..     ...                    ...                        ...    ...     ...
# 496  False                  False                      False  False   False
# 497  False                  False                      False  False   False
# 498  False                  False                      False  False   False
# 499  False                  False                      False  False   False
# 500  False                  False                      False  False   False
#
# ...

# %%
#PREGUNTA 7
#De "porcino.xlsx". ¿Cuántos porcinos Macho son en total?
p7=porcinos[porcinos["Sexo"]=="MACHO"]
len(p7)
# Out:
# 379

# %%
#PREGUNTA 8
#De "titanic.csv". ¿Cuántas mujeres de 38 años murieron?
p8=titanic[(titanic["Age"]==38)&(titanic["Sex"]=="female")&(titanic["Survived"]=="Died")]
p8
# Out:
#      Count  PassengerId Survived  Pclass                       Name     Sex  \
# 357      1          358     Died       2  Funk, Miss. Annie Clemmer  female
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 357  38.0      0      0  237671  13.0   NaN        S

# %%
len(p8)
# Out:
# 1

# %%
#PREGUNTA 9
#De "porcino.xlsx". ¿Cuántos porcinos tienen la calidad de la carne 
#"Estandar"?
p9=porcinos[porcinos["Calidad de la carne"]=="Estandar"]
len(p9)
# Out:
# 230

# %%
#PREGUNTA 10
#Sobre "w_university_r.csv". ¿Cuántas universidades de Perú?
p10=universidad[universidad["Location"]=="Peru"]
p10
# Out:
#       World Rank                             Institution Location  \
# 1505        1506    Cayetano Heredia Peruvian University     Peru
# 1580        1581  Pontifical Catholic University of Peru     Peru
#
#       National Rank Education Rank Employability Rank Faculty Rank  \
# 1505              1              -                  -            -
# 1580              2              -               1339            -
#
#      Research Rank  Score
# 1505          1437   67.7
# 1580          1506   67.3

# %%
#PREGUNTA 11
#Sobre "w_university_r.csv".¿Cuál es el "Score" de la mejor U del Perú?
p10[p10["Score"]==p10["Score"].max()]
# Out:
#       World Rank                           Institution Location  \
# 1505        1506  Cayetano Heredia Peruvian University     Peru
#
#       National Rank Education Rank Employability Rank Faculty Rank  \
# 1505              1              -                  -            -
#
#      Research Rank  Score
# 1505          1437   67.7

# %%
#PREGUNTA 12
#De "porcino.xlsx". ¿Cuántos porcinos Hembra tienen la calidad
#de carne "Estandar"?
p12=porcinos[(porcinos["Sexo"]=="HEMBRA")&(porcinos["Calidad de la carne"]=="Estandar")]
len(p12)
# Out:
# 27

# %%
#PREGUNTA 13
#Sobre "w_university_r.csv". ¿Cuál es el "Score" de la última
#universidad de Chile en aparecer?
p13=universidad[universidad["Location"]=="Chile"]
pregunta=p13[p13["Score"]==p13["Score"].min()]
pregunta
# Out:
#       World Rank             Institution Location  National Rank  \
# 1998        1999  University of Tarapacá    Chile             16
#
#      Education Rank Employability Rank Faculty Rank Research Rank  Score
# 1998              -                  -            -          1925   65.7

# %%
#PREGUNTA 14
#De "porcino.xlsx". ¿Cuántos porcinos Hembra de la Region
# "O'Higgins" son en total?
p14=porcinos[(porcinos["Sexo"]=="HEMBRA")&(porcinos["Region"]=="O´Higgins")]
len(p14)
# Out:
# 106

# %%
#PREGUNTA 15
#De "music.csv". ¿Cuántos valores nulos tiene?
musica.isnull().sum()
# Out:
# Year            0
# Format          0
# Revenue [m$]    0
# dtype: int64

# %%
#PREGUNTA 16
#De "titanic.csv". ¿Cuántos valores nulos tiene?
titanic.isnull().sum().sum()
# Out:
# 866

# %%
177+687+2
# Out:
# 866

# %%
#PREGUNTA 17
#De "music.csv". ¿El Format "Blu Ray en qué año obtuvo el valor 
#más alto en revenue"?
musica[musica["Format"]=="Blu Ray"]
# Out:
# Empty DataFrame
# Columns: [Year, Format, Revenue [m$]]
# Index: []

# %%
#PREGUNTA 18
#De "titanic.csv". ¿Cuántos varones sobrevivieron?
p18=titanic[(titanic["Sex"]=="male")&(titanic["Survived"]=="Survived")]
len(p18)
# Out:
# 109

# %%
#PREGUNTA 19
#De "titanic.csv". ¿Cuántas personas sobrevivieron?
p19=titanic[titanic["Survived"]=="Survived"]
len(p19)
# Out:
# 342

# %%
#PREGUNTA 20
#Sobre "w_university_r.csv". ¿Cuántos valores nulos tiene?

# %%
universidad.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## FIN DEL EXAMEN
